# %% [markdown]
# <a href="https://colab.research.google.com/github/msoc10/SpuBigData/blob/main/Treemap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
file_path = r'/content/ind_nifty100list.csv'

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                    Company Name                    Industry  \
# 0                                ABB India Ltd.               Capital Goods
# 1                   Adani Energy Solutions Ltd.                       Power
# 2                        Adani Enterprises Ltd.             Metals & Mining
# 3                       Adani Green Energy Ltd.                       Power
# 4    Adani Ports and Special Economic Zone Ltd.                    Services
# ..                                          ...                         ...
# 96                         Varun Beverages Ltd.  Fast Moving Consumer Goods
# 97                                 Vedanta Ltd.             Metals & Mining
# 98                                   Wipro Ltd.      Information Technology
# 99                                  Zomato Ltd.           Consumer Services
# 100                     Zydus Lifesciences Ltd.                  Healthcare
#
#          Symbol Series     ISIN Code
# ...

# %%
fig = px.treemap(df, path=['Industry'], title='Industry Frequency TreeMap')

# Show the TreeMap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(df, path=['Industry'], title='Industry Frequency TreeMap',
                 color_discrete_sequence=['green', 'blue', 'orange', 'red', 'purple'])

# Customize label appearance
fig.update_layout(treemaplabels=dict(family="Arial", size=12, color='white'))

# Show the TreeMap
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-009840a806d9> in <cell line: 5>()
#       3
#       4 # Customize label appearance
# ----> 5 fig.update_layout(treemaplabels=dict(family="Arial", size=12, color='white'))
#       6
#       7 # Show the TreeMap
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_figure.py in update_layout(self, dict1, overwrite, **kwargs)
#     773
#     774         """
# --> 775         return super(Figure, self).update_layout(dict1, overwrite, **kwargs)
#     776
#     777     def for_each_trace(
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1391             The Figure object that the update_layout method was called on
#    1392         """
# -> 1393         self.layout.update(dict1, overwrite=overwrite, **kwargs)
# ...

# %%
fig = px.treemap(df, path=['Symbol'], title=' Company Name As Symbol Frequency TreeMap', hover_data=['Company Name'],
                 color_discrete_sequence=px.colors.qualitative.Set1)

# Show the TreeMap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(df, path=['Industry'], title='Industry Frequency TreeMap',
                 color_discrete_sequence=px.colors.qualitative.Set1)

# Show the TreeMap
fig.show()

# Define a callback function to update the treemap when clicking on a sector
def update_treemap(trace, points, selector):
    selected_sector = points.point_numbers[0] if points.point_numbers else None

    if selected_sector is not None:
        # Filter data based on the selected sector
        selected_sector = df['Industry'].unique()[selected_sector]
        filtered_data = df[df['Industry'] == selected_sector]

        # Create a treemap for the selected sector
        updated_fig = px.treemap(filtered_data, path=['Company Name'],
                                 title=f'Companies in {selected_sector}',
                                 color_discrete_sequence=px.colors.qualitative.Set2)

        # Display the list of companies in the console
        print(f'Companies in {selected_sector}: {filtered_data["Company Name"].tolist()}')

        # Update the layout to show the new treemap
        updated_fig.update_layout(title=f'Companies in {selected_sector}')
        updated_fig.show()

# Add click event to the initial treemap
fig.data[0].on_click(update_treemap)

# Display the initial treemap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
